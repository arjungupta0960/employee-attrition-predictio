# %% [markdown]
# EMPLOYEE ATTRITION RISK PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       ï»¿Age Attrition     BusinessTravel  DailyRate              Department  \
# 0         41       Yes      Travel_Rarely       1102                   Sales
# 1         49        No  Travel_Frequently        279  Research & Development
# 2         37       Yes      Travel_Rarely       1373  Research & Development
# 3         33        No  Travel_Frequently       1392  Research & Development
# 4         27        No      Travel_Rarely        591  Research & Development
# ...      ...       ...                ...        ...                     ...
# 1465      36        No  Travel_Frequently        884  Research & Development
# 1466      39        No      Travel_Rarely        613  Research & Development
# 1467      27        No      Travel_Rarely        155  Research & Development
# 1468      49        No  Travel_Frequently       1023                   Sales
# 1469      34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
df.head()
# Out:
#    ï»¿Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    ï»¿Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿Age                    1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#             ï»¿Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#for checking duplicates value\    #the duplicates data and the drop duplicates data are same count
print(df.duplicated().value_counts())
df.drop_duplicates(inplace = True)
print(len(df))
# Out:
# False    1470
# Name: count, dtype: int64
# 1470

# %%
df.isnull()
# Out:
#       ï»¿Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0      False      False           False      False       False
# 1      False      False           False      False       False
# 2      False      False           False      False       False
# 3      False      False           False      False       False
# 4      False      False           False      False       False
# ...      ...        ...             ...        ...         ...
# 1465   False      False           False      False       False
# 1466   False      False           False      False       False
# 1467   False      False           False      False       False
# 1468   False      False           False      False       False
# 1469   False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
#checking missing value
df.isnull().sum()
# Out:
# ï»¿Age                      0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#target variable
plt.figure(figsize=(15,5))
plt.rc("font",size=14)
sns.countplot(y='Attrition',data=df)
plt.show()

# %%
#Exploratory data analysis (EDA)
plt.figure(figsize=(10,5))
sns.countplot(x='Department',hue='Attrition',data=df,palette='hot')
plt.title("Attrition w.r.t Department")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender',hue='Attrition',data=df,palette='hot')
plt.title("Attrition w.r.t Gender")
plt.legend(loc='best')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df['count'] = 1

# %%
df.groupby(["Gender","Attrition"]).agg({"count":"sum"})
# Out:
#                   count
# Gender Attrition
# Female No           501
#        Yes           87
# Male   No           732
#        Yes          150

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='EducationField',hue='Attrition',data=df,palette='hot')
plt.title("Attrition w.r.t EducationField")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='JobSatisfaction',hue='Attrition',data=df,palette='hot')
plt.title("Attrition w.r.t JobSatisfaction")
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='JobRole',hue='Attrition',data=df,palette='hot')
plt.title("Attrition w.r.t JobRole")
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show()

# %%
#distribution of age
plt.figure(figsize=(12,5))
sns.distplot(df['ï»¿Age'],hist=False)
plt.show()

# %%
ordinal_features = ['Education', 'EnvironmentSatisfaction','MonthlyIncome', 'JobInvolvement','YearsAtCompany', 'JobSatisfaction', 'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance']
df[ordinal_features].head()
# Out:
#    Education  EnvironmentSatisfaction  MonthlyIncome  JobInvolvement  \
# 0          2                        2           5993               3
# 1          1                        3           5130               2
# 2          2                        4           2090               2
# 3          4                        4           2909               3
# 4          1                        1           3468               3
#
#    YearsAtCompany  JobSatisfaction  PerformanceRating  \
# 0               6                4                  3
# 1              10                2                  4
# 2               0                3                  3
# 3               8                3                  3
# 4               2                2                  3
#
#    RelationshipSatisfaction  WorkLifeBalance
# 0                         1                1
# 1                         4                3
# 2                         2                3
# ...

# %%
ordinal_features
# Out:
# ['Education',
#  'EnvironmentSatisfaction',
#  'MonthlyIncome',
#  'JobInvolvement',
#  'YearsAtCompany',
#  'JobSatisfaction',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'WorkLifeBalance']

# %%
#Label Encoding
df[ordinal_features]
# Out:
#       Education  EnvironmentSatisfaction  MonthlyIncome  JobInvolvement  \
# 0             2                        2           5993               3
# 1             1                        3           5130               2
# 2             2                        4           2090               2
# 3             4                        4           2909               3
# 4             1                        1           3468               3
# ...         ...                      ...            ...             ...
# 1465          2                        3           2571               4
# 1466          1                        4           9991               2
# 1467          3                        2           6142               4
# 1468          3                        4           5390               2
# 1469          3                        2           4404               4
#
#       YearsAtCompany  JobSatisfaction  PerformanceRating  \
# ...

# %%
#subjective categorical data - witn no particulaarly defined order?
edu_map = { 1: 'Below College', 2: 'college', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'}
plt.figure(figsize=(12,5))
sns.countplot(x=df['Education'].map(edu_map), hue='Attrition', data=df, palette ='hot')
plt.title("Education W.R.T Attrition")
plt.show()

# %%
# Target variable(Attrition)
df['Attrition'].replace({'No':0,'Yes':1})
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
df['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 1465      Male
# 1466      Male
# 1467      Male
# 1468      Male
# 1469      Male
# Name: Gender, Length: 1470, dtype: object

# %%
#encode binaray variables
df['OverTime'] = df['OverTime'].map({'No':0,'Yes':1})
df['Gender'] = df['Gender'].map({'Male':0,'Female':1})

# %%
#encode categorical columns which are ordinal, use labelEncoding
#apply Label encoder to df_categorical
from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']
label_encoders = {}
for column in encoding_cols:
    label_encoders [column] = LabelEncoder()
    df[column] = label_encoders [column].fit_transform(df[column])

# %%
#look at final data
df.head()
# Out:
#    ï»¿Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41       Yes               2       1102           2                 1
# 1      49        No               1        279           1                 8
# 2      37       Yes               2       1373           1                 2
# 3      33        No               1       1392           1                 3
# 4      27        No               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
x=df.drop(['Attrition','Over18'], axis=1) # Input Feature
y=df['Attrition'].values # Output

# %%
# should be oversample the minoraty class or shuould be undersample the majority class?
# to balance this data

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#balance data set
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
print(Counter(y))
rus = RandomOverSampler(random_state = 42)
X_over, y_over = rus.fit_resample(x,y)
print(Counter(y_over))
# Out:
# Counter({'No': 1233, 'Yes': 237})
# Counter({'Yes': 1233, 'No': 1233})

# %%
#Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size=0.2, random_state=42)

# %%
# Sanity the data training and testing set
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1972, 34)
# (1972,)
# (494, 34)
# (494,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score

# %%
logreg=LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction = logreg.predict(X_test)
cnf_matrix = confusion_matrix(y_test, prediction) 
print("Accuracy Score =", accuracy_score(y_test, prediction))
# Out:
# Accuracy Score = 0.6417004048582996

# %%
fig = plt.figure(figsize = (15,6))
axl = fig.add_subplot(1,2,1) 
ax1 = sns.heatmap(pd.DataFrame(cnf_matrix), annot = True, cmap = 'Blues', fmt = 'd') 
bottom, top = ax1.get_ylim()
axl.set_ylim(bottom + 0.5, top - 0.5)
plt.xlabel('Predicted')
plt.ylabel('Expected')
# Out:
# Text(153.22222222222223, 0.5, 'Expected')

# %%
import pandas as pd

# Convert y_test (numpy array) to a Pandas Series
y_test_series = pd.Series(y_test)

# Now you can use map() safely
y_test_binary = y_test_series.map({'No': 0, 'Yes': 1})

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Predict probabilities
y_pred_proba = logreg.predict_proba(X_test)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test_binary, y_pred_proba)
auc = roc_auc_score(y_test_binary, y_pred_proba)

# Plot ROC
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, color='blue', label=f'LogReg (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal line
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
